# %%
# Define opcodes
opcodes = {
    "00": "JUMP",
    "01000": "SKIPCLEAR",
    "01001": "SKIPSET",
    "01010": "CLEAR",
    "01011": "SET",
    "0110": "READ",
    "01110": "DELAY",
    "011110000": "SKIPNACK",
    "011110001": "SKIPACK",
    "011110010": "WRITELOW",
    "011110011": "WRITEHI",
    "011110100": "USER0",
    # Add more opcodes here
    "011111110": "USER9",
    "011111111": "STOP",
    "1": "WRITE"
}

memory = [
    "011101111",     "101110110",     "101000000",     "100000000",     "100001110",
    "011111111",     "101110110",     "101000000",     "100000010",     "100000000",
    "101111101",     "100000000",     "100001100",     "100100011",     "100000001",
    "011111111",     "011101111",     "101110110",     "101000000",     "100000000",
    "100001111",     "011111111",     "011101111",     "101110110",     "101000000",
    "100010101",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001010",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001011",     "100010000",     "011111111",     "101110110",     "101000000",
    "100001100",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001101",     "100010000",     "011111111",     "101110110",     "101000000",
    "100001110",     "100000011",     "011111111",     "101110110",     "101000000",
    "100001111",     "100000011",     "011111111",     "101110110",     "101000000",
    "100010000",     "100000001",     "011111111",     "101110110",     "101000000",
    "100010001",     "111111011",     "011111111",     "101110110",     "101000000",
    "100010010",     "100111011",     "011111111",     "101110110",     "101000000",
    "100010011",     "101101000",     "011111111",     "101110110",     "101000000",
    "100010100",     "100110001",     "011111111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "101110110",     "101000000",
    "100100011",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100100",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100101",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100110",     "111100111",     "011111111",     "101110110",     "101000000",
    "100011001",     "100000011",     "011111111",     "101110110",     "101000000",
    "100101001",     "100000011",     "011111111",     "101110110",     "101000000",
    "100101010",     "100000011",     "011111111",     "101110110",     "101000000",
    "111110010",     "100000001",     "011111111",     "101110110",     "101000000",
    "111110011",     "100000001",     "011111111",     "101110110",     "101000000",
    "111111001",     "101111111",     "011111111",     "101110110",     "101000000",
    "111111010",     "100000011",     "011111111",     "000010011",     "011111110",
    "011111110",     "011111110",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010100000",
    "010100001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010000000",     "000010100",     "010000001",
    "000011001",     "000010011",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010110000",
    "010100001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010010000",     "000001111",     "010000001",
    "000011110",     "000011000",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010100000",
    "010110001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010000000",     "000000000",     "010010001",
    "000001111",     "000011101",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010110000",
    "010110001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010010000",     "000011001",     "010010001",
    "000010100",     "000100010",
]


# Extract value from WRITE instruction and format in hexadecimal
def extract_value(instruction):
    return hex(int(instruction[1:], 2))

# Identify opcode and extract value if applicable
def identify_opcode_and_value(instruction):
    for opcode, action in opcodes.items():
        if instruction.startswith(opcode):
            if opcode == "1":  # WRITE opcode
                value = extract_value(instruction)
                return action, value
            else:
                return action, None
    return "Unknown", None

def execute_program(memory):
    PC = 0
    while PC < len(memory):
        instruction = memory[PC]
        action, value = identify_opcode_and_value(instruction)
        if action == "JUMP":
            # Extract the jump destination from the instruction
            jump_address = int(instruction[2:], 2)
            PC = jump_address * 8
            print(f"Jumping to address: {PC}")
            continue
        elif value is not None:
            print(f"Address: {PC}, Instruction: {instruction}, Action: {action} {value}")
        else:
            print(f"Address: {PC}, Instruction: {instruction}, Action: {action}")
        PC += 1

# Example memory data








# Execute program
execute_program(memory)
# Out:
# Address: 0, Instruction: 011101111, Action: DELAY
# Address: 1, Instruction: 101110110, Action: WRITE 0x76
# Address: 2, Instruction: 101000000, Action: WRITE 0x40
# Address: 3, Instruction: 100000000, Action: WRITE 0x0
# Address: 4, Instruction: 100001110, Action: WRITE 0xe
# Address: 5, Instruction: 011111111, Action: STOP
# Address: 6, Instruction: 101110110, Action: WRITE 0x76
# Address: 7, Instruction: 101000000, Action: WRITE 0x40
# Address: 8, Instruction: 100000010, Action: WRITE 0x2
# Address: 9, Instruction: 100000000, Action: WRITE 0x0
# Address: 10, Instruction: 101111101, Action: WRITE 0x7d
# Address: 11, Instruction: 100000000, Action: WRITE 0x0
# Address: 12, Instruction: 100001100, Action: WRITE 0xc
# Address: 13, Instruction: 100100011, Action: WRITE 0x23
# Address: 14, Instruction: 100000001, Action: WRITE 0x1
# Address: 15, Instruction: 011111111, Action: STOP
# Address: 16, Instruction: 011101111, Action: DELAY
# ...

# %%
def parse_input(input_data):
    memory_data = []
    lines = input_data.strip().split("\n")
    for line in lines:
        binary_index, data = line.split("=>")
        data = data.strip().split('"')[1]
        memory_data.append(data)
    return memory_data

def generate_memory_declaration(memory_data):
    declaration = "memory_data = [\n"
    for i, data in enumerate(memory_data):
        if i % 5 == 0 and i != 0:
            declaration += "\n"
        declaration += f'    "{data}", '
    declaration += "\n]"
    return declaration

input_data = """\
            when "0000000000" => data <= "011101111";
            when "0000000001" => data <= "101110110";
            when "0000000010" => data <= "101000000";
            when "0000000011" => data <= "100000000";
            when "0000000100" => data <= "100001110";
            when "0000000101" => data <= "011111111";
            when "0000000110" => data <= "101110110";
            when "0000000111" => data <= "101000000";
            when "0000001000" => data <= "100000010";
            when "0000001001" => data <= "100000000";
            when "0000001010" => data <= "101111101";
            when "0000001011" => data <= "100000000";
            when "0000001100" => data <= "100001100";
            when "0000001101" => data <= "100100011";
            when "0000001110" => data <= "100000001";
            when "0000001111" => data <= "011111111";
            when "0000010000" => data <= "011101111";
            when "0000010001" => data <= "101110110";
            when "0000010010" => data <= "101000000";
            when "0000010011" => data <= "100000000";
            when "0000010100" => data <= "100001111";
            when "0000010101" => data <= "011111111";
            when "0000010110" => data <= "011101111";
            when "0000010111" => data <= "101110110";
            when "0000011000" => data <= "101000000";
            when "0000011001" => data <= "100010101";
            when "0000011010" => data <= "100000001";
            when "0000011011" => data <= "011111111";
            when "0000011100" => data <= "101110110"; -- Rec Mixer Left Mic
            when "0000011101" => data <= "101000000"; -- Write Address 0x40
            when "0000011110" => data <= "100001010"; -- Write Address 0x0A
            when "0000011111" => data <= "100000001"; -- Write Address 0x01 (Enable Left Mixer)
            when "0000100000" => data <= "011111111";
            when "0000100001" => data <= "101110110"; -- Rec Mixer Left Aux
            when "0000100010" => data <= "101000000"; -- Write Address 0x40
            when "0000100011" => data <= "100001011"; -- Write Address 0x0B
            when "0000100100" => data <= "100010000"; -- Write Address 0x10 (Mute Aux Left & LDBOOST 20 dB)
            when "0000100101" => data <= "011111111";
            when "0000100110" => data <= "101110110"; -- Rec Mixer Right
            when "0000100111" => data <= "101000000"; -- Write Address 0x40
            when "0000101000" => data <= "100001100"; -- Write Address 0x0C
            when "0000101001" => data <= "100000001"; -- Write Address 0x01 (Enable Right Mixer)
            when "0000101010" => data <= "011111111";
            when "0000101011" => data <= "101110110"; -- Rec Mixer Right Aux
            when "0000101100" => data <= "101000000"; -- Write Address 0x40
            when "0000101101" => data <= "100001101"; -- Write Address 0x0D
            when "0000101110" => data <= "100010000"; -- Write Address 0x10 (Mute Aux Right & LDBOOST 20 dB)
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- Left Differential Input Volume Control
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100001110"; -- Write Address 0x0E
            when "0000110011" => data <= "100000011"; -- Write Address 0x3 (Enable & Unmute)
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- Right Differential Input Volume Control
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100001111"; -- Write Address 0x0F
            when "0000110011" => data <= "100000011"; -- Write Address 0x3 (Enable & Unmute)
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- Mic Bias
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100010000"; -- Write Address 0x10
            when "0000110011" => data <= "100000001"; -- Write Address 0x01 (Enable Bias)
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- ALC Control 0
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100010001"; -- Write Address 0x11
            when "0000110011" => data <= "111111011"; -- Write Address 0xFB
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- ALC Control 1
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100010010"; -- Write Address 0x12
            when "0000110011" => data <= "100111011"; -- Write Address 0x3B
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- ALC Control 2
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100010011"; -- Write Address 0x13
            when "0000110011" => data <= "101101000"; -- Write Address 0x68
            when "0000101111" => data <= "011111111";
            when "0000110000" => data <= "101110110"; -- ALC Control 3
            when "0000110001" => data <= "101000000"; -- Write Address 0x40
            when "0000110010" => data <= "100010100"; -- Write Address 0x14
            when "0000110011" => data <= "100110001"; -- Write Address 0x31
            when "0000110100" => data <= "011111111";
            when "0000110101" => data <= "101110110";
            when "0000110110" => data <= "101000000";
            when "0000110111" => data <= "100011100";
            when "0000111000" => data <= "100100001";
            when "0000111001" => data <= "011111111";
            when "0000111010" => data <= "101110110";
            when "0000111011" => data <= "101000000";
            when "0000111100" => data <= "100011110";
            when "0000111101" => data <= "101000001";
            when "0000111110" => data <= "011111111";
            when "0000111111" => data <= "101110110";
            when "0001000000" => data <= "101000000";
            when "0001000001" => data <= "100100011";
            when "0001000010" => data <= "111100111";
            when "0001000011" => data <= "011111111";
            when "0001000100" => data <= "101110110";
            when "0001000101" => data <= "101000000";
            when "0001000110" => data <= "100100100";
            when "0001000111" => data <= "111100111";
            when "0001001000" => data <= "011111111";
            when "0001001001" => data <= "101110110";
            when "0001001010" => data <= "101000000";
            when "0001001011" => data <= "100100101";
            when "0001001100" => data <= "111100111";
            when "0001001101" => data <= "011111111";
            when "0001001110" => data <= "101110110";
            when "0001001111" => data <= "101000000";
            when "0001010000" => data <= "100100110";
            when "0001010001" => data <= "111100111";
            when "0001010010" => data <= "011111111";
            when "0001010011" => data <= "101110110";
            when "0001010100" => data <= "101000000";
            when "0001010101" => data <= "100011001";
            when "0001010110" => data <= "100000011";
            when "0001010111" => data <= "011111111";
            when "0001011000" => data <= "101110110";
            when "0001011001" => data <= "101000000";
            when "0001011010" => data <= "100101001";
            when "0001011011" => data <= "100000011";
            when "0001011100" => data <= "011111111";
            when "0001011101" => data <= "101110110";
            when "0001011110" => data <= "101000000";
            when "0001011111" => data <= "100101010";
            when "0001100000" => data <= "100000011";
            when "0001100001" => data <= "011111111";
            when "0001100010" => data <= "101110110";
            when "0001100011" => data <= "101000000";
            when "0001100100" => data <= "111110010";
            when "0001100101" => data <= "100000001";
            when "0001100110" => data <= "011111111";
            when "0001100111" => data <= "101110110";
            when "0001101000" => data <= "101000000";
            when "0001101001" => data <= "111110011";
            when "0001101010" => data <= "100000001";
            when "0001101011" => data <= "011111111";
            when "0001101100" => data <= "101110110";
            when "0001101101" => data <= "101000000";
            when "0001101110" => data <= "111111001";
            when "0001101111" => data <= "101111111";
            when "0001110000" => data <= "011111111";
            when "0001110001" => data <= "101110110";
            when "0001110010" => data <= "101000000";
            when "0001110011" => data <= "111111010";
            when "0001110100" => data <= "100000011";
            when "0001110101" => data <= "011111111";
            when "0001110110" => data <= "000010011";
            when "0001110111" => data <= "011111110";
            when "0001111000" => data <= "011111110";
            when "0001111001" => data <= "011111110";
            when "0001111010" => data <= "011111110";
            when "0001111011" => data <= "011111110";
            when "0001111100" => data <= "011111110";
            when "0001111101" => data <= "101110110";
            when "0001111110" => data <= "101000000";
            when "0001111111" => data <= "100011100";
            when "0010000000" => data <= "100100000";
            when "0010000001" => data <= "011111111";
            when "0010000010" => data <= "101110110";
            when "0010000011" => data <= "101000000";
            when "0010000100" => data <= "100011110";
            when "0010000101" => data <= "101000000";
            when "0010000110" => data <= "011111111";
            when "0010000111" => data <= "011101111";
            when "0010001000" => data <= "011101111";
            when "0010001001" => data <= "011101111";
            when "0010001010" => data <= "011101111";
            when "0010001011" => data <= "010100000";
            when "0010001100" => data <= "010100001";
            when "0010001101" => data <= "011101111";
            when "0010001110" => data <= "011101111";
            when "0010001111" => data <= "101110110";
            when "0010010000" => data <= "101000000";
            when "0010010001" => data <= "100011100";
            when "0010010010" => data <= "100100001";
            when "0010010011" => data <= "011111111";
            when "0010010100" => data <= "101110110";
            when "0010010101" => data <= "101000000";
            when "0010010110" => data <= "100011110";
            when "0010010111" => data <= "101000001";
            when "0010011000" => data <= "011111111";
            when "0010011001" => data <= "011111110";
            when "0010011010" => data <= "011111110";
            when "0010011011" => data <= "011111110";
            when "0010011100" => data <= "011111110";
            when "0010011101" => data <= "010000000";
            when "0010011110" => data <= "000010100";
            when "0010011111" => data <= "010000001";
            when "0010100000" => data <= "000011001";
            when "0010100001" => data <= "000010011";
            when "0010100010" => data <= "011111110";
            when "0010100011" => data <= "011111110";
            when "0010100100" => data <= "011111110";
            when "0010100101" => data <= "101110110";
            when "0010100110" => data <= "101000000";
            when "0010100111" => data <= "100011100";
            when "0010101000" => data <= "100100000";
            when "0010101001" => data <= "011111111";
            when "0010101010" => data <= "101110110";
            when "0010101011" => data <= "101000000";
            when "0010101100" => data <= "100011110";
            when "0010101101" => data <= "101000000";
            when "0010101110" => data <= "011111111";
            when "0010101111" => data <= "011101111";
            when "0010110000" => data <= "011101111";
            when "0010110001" => data <= "011101111";
            when "0010110010" => data <= "011101111";
            when "0010110011" => data <= "010110000";
            when "0010110100" => data <= "010100001";
            when "0010110101" => data <= "011101111";
            when "0010110110" => data <= "011101111";
            when "0010110111" => data <= "101110110";
            when "0010111000" => data <= "101000000";
            when "0010111001" => data <= "100011100";
            when "0010111010" => data <= "100100001";
            when "0010111011" => data <= "011111111";
            when "0010111100" => data <= "101110110";
            when "0010111101" => data <= "101000000";
            when "0010111110" => data <= "100011110";
            when "0010111111" => data <= "101000001";
            when "0011000000" => data <= "011111111";
            when "0011000001" => data <= "011111110";
            when "0011000010" => data <= "011111110";
            when "0011000011" => data <= "011111110";
            when "0011000100" => data <= "011111110";
            when "0011000101" => data <= "010010000";
            when "0011000110" => data <= "000001111";
            when "0011000111" => data <= "010000001";
            when "0011001000" => data <= "000011110";
            when "0011001001" => data <= "000011000";
            when "0011001010" => data <= "011111110";
            when "0011001011" => data <= "011111110";
            when "0011001100" => data <= "011111110";
            when "0011001101" => data <= "101110110";
            when "0011001110" => data <= "101000000";
            when "0011001111" => data <= "100011100";
            when "0011010000" => data <= "100100000";
            when "0011010001" => data <= "011111111";
            when "0011010010" => data <= "101110110";
            when "0011010011" => data <= "101000000";
            when "0011010100" => data <= "100011110";
            when "0011010101" => data <= "101000000";
            when "0011010110" => data <= "011111111";
            when "0011010111" => data <= "011101111";
            when "0011011000" => data <= "011101111";
            when "0011011001" => data <= "011101111";
            when "0011011010" => data <= "011101111";
            when "0011011011" => data <= "010100000";
            when "0011011100" => data <= "010110001";
            when "0011011101" => data <= "011101111";
            when "0011011110" => data <= "011101111";
            when "0011011111" => data <= "101110110";
            when "0011100000" => data <= "101000000";
            when "0011100001" => data <= "100011100";
            when "0011100010" => data <= "100100001";
            when "0011100011" => data <= "011111111";
            when "0011100100" => data <= "101110110";
            when "0011100101" => data <= "101000000";
            when "0011100110" => data <= "100011110";
            when "0011100111" => data <= "101000001";
            when "0011101000" => data <= "011111111";
            when "0011101001" => data <= "011111110";
            when "0011101010" => data <= "011111110";
            when "0011101011" => data <= "011111110";
            when "0011101100" => data <= "011111110";
            when "0011101101" => data <= "010000000";
            when "0011101110" => data <= "000000000";
            when "0011101111" => data <= "010010001";
            when "0011110000" => data <= "000001111";
            when "0011110001" => data <= "000011101";
            when "0011110010" => data <= "011111110";
            when "0011110011" => data <= "011111110";
            when "0011110100" => data <= "011111110";
            when "0011110101" => data <= "101110110";
            when "0011110110" => data <= "101000000";
            when "0011110111" => data <= "100011100";
            when "0011111000" => data <= "100100000";
            when "0011111001" => data <= "011111111";
            when "0011111010" => data <= "101110110";
            when "0011111011" => data <= "101000000";
            when "0011111100" => data <= "100011110";
            when "0011111101" => data <= "101000000";
            when "0011111110" => data <= "011111111";
            when "0011111111" => data <= "011101111";
            when "0100000000" => data <= "011101111";
            when "0100000001" => data <= "011101111";
            when "0100000010" => data <= "011101111";
            when "0100000011" => data <= "010110000";
            when "0100000100" => data <= "010110001";
            when "0100000101" => data <= "011101111";
            when "0100000110" => data <= "011101111";
            when "0100000111" => data <= "101110110";
            when "0100001000" => data <= "101000000";
            when "0100001001" => data <= "100011100";
            when "0100001010" => data <= "100100001";
            when "0100001011" => data <= "011111111";
            when "0100001100" => data <= "101110110";
            when "0100001101" => data <= "101000000";
            when "0100001110" => data <= "100011110";
            when "0100001111" => data <= "101000001";
            when "0100010000" => data <= "011111111";
            when "0100010001" => data <= "011111110";
            when "0100010010" => data <= "011111110";
            when "0100010011" => data <= "011111110";
            when "0100010100" => data <= "011111110";
            when "0100010101" => data <= "010010000";
            when "0100010110" => data <= "000011001";
            when "0100010111" => data <= "010010001";
            when "0100011000" => data <= "000010100";
            when "0100011001" => data <= "000100010";
"""

parsed_data = parse_input(input_data)
print(generate_memory_declaration(parsed_data))
# Out:
# memory_data = [
#     "011101111",     "101110110",     "101000000",     "100000000",     "100001110",
#     "011111111",     "101110110",     "101000000",     "100000010",     "100000000",
#     "101111101",     "100000000",     "100001100",     "100100011",     "100000001",
#     "011111111",     "011101111",     "101110110",     "101000000",     "100000000",
#     "100001111",     "011111111",     "011101111",     "101110110",     "101000000",
#     "100010101",     "100000001",     "011111111",     "101110110",     "101000000",
#     "100001010",     "100000001",     "011111111",     "101110110",     "101000000",
#     "100001011",     "100010000",     "011111111",     "101110110",     "101000000",
#     "100001100",     "100000001",     "011111111",     "101110110",     "101000000",
#     "100001101",     "100010000",     "011111111",     "101110110",     "101000000",
#     "100001110",     "100000011",     "011111111",     "101110110",     "101000000",
# ...

# %%
def format_memory(memory):
    formatted_memory = []
    for index, value in enumerate(memory):
        binary_index = format(index, '010b')  # Convert index to 10-bit binary
        formatted_memory.append(f'when "{binary_index}" => data <= "{value}";')
    return formatted_memory

# Example usage:




memory_data = [
    "011101111",     "101110110",     "101000000",     "100000000",     "100001110",
    "011111111",     "101110110",     "101000000",     "100000010",     "100000000",
    "101111101",     "100000000",     "100001100",     "100100011",     "100000001",
    "011111111",     "011101111",     "101110110",     "101000000",     "100000000",
    "100001111",     "011111111",     "011101111",     "101110110",     "101000000",
    "100010101",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001010",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001011",     "100010000",     "011111111",     "101110110",     "101000000",
    "100001100",     "100000001",     "011111111",     "101110110",     "101000000",
    "100001101",     "100010000",     "011111111",     "101110110",     "101000000",
    "100001110",     "100000011",     "011111111",     "101110110",     "101000000",
    "100001111",     "100000011",     "011111111",     "101110110",     "101000000",
    "100010000",     "100000001",     "011111111",     "101110110",     "101000000",
    "100010001",     "111111011",     "011111111",     "101110110",     "101000000",
    "100010010",     "100111011",     "011111111",     "101110110",     "101000000",
    "100010011",     "101101000",     "011111111",     "101110110",     "101000000",
    "100010100",     "100110001",     "011111111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "101110110",     "101000000",
    "100100011",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100100",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100101",     "111100111",     "011111111",     "101110110",     "101000000",
    "100100110",     "111100111",     "011111111",     "101110110",     "101000000",
    "100011001",     "100000011",     "011111111",     "101110110",     "101000000",
    "100101001",     "100000011",     "011111111",     "101110110",     "101000000",
    "100101010",     "100000011",     "011111111",     "101110110",     "101000000",
    "111110010",     "100000001",     "011111111",     "101110110",     "101000000",
    "111110011",     "100000001",     "011111111",     "101110110",     "101000000",
    "111111001",     "101111111",     "011111111",     "101110110",     "101000000",
    "111111010",     "100000011",     "011111111",     "000010011",     "011111110",
    "011111110",     "011111110",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010100000",
    "010100001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010000000",     "000010100",     "010000001",
    "000011001",     "000010011",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010110000",
    "010100001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010010000",     "000001111",     "010000001",
    "000011110",     "000011000",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010100000",
    "010110001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010000000",     "000000000",     "010010001",
    "000001111",     "000011101",     "011111110",     "011111110",     "011111110",
    "101110110",     "101000000",     "100011100",     "100100000",     "011111111",
    "101110110",     "101000000",     "100011110",     "101000000",     "011111111",
    "011101111",     "011101111",     "011101111",     "011101111",     "010110000",
    "010110001",     "011101111",     "011101111",     "101110110",     "101000000",
    "100011100",     "100100001",     "011111111",     "101110110",     "101000000",
    "100011110",     "101000001",     "011111111",     "011111110",     "011111110",
    "011111110",     "011111110",     "010010000",     "000011001",     "010010001",
    "000010100",     "000100010",
]



formatted_memory = format_memory(memory_data)

# Print the formatted memory
for line in formatted_memory:
    print(line)
# Out:
# when "0000000000" => data <= "011101111";
# when "0000000001" => data <= "101110110";
# when "0000000010" => data <= "101000000";
# when "0000000011" => data <= "100000000";
# when "0000000100" => data <= "100001110";
# when "0000000101" => data <= "011111111";
# when "0000000110" => data <= "101110110";
# when "0000000111" => data <= "101000000";
# when "0000001000" => data <= "100000010";
# when "0000001001" => data <= "100000000";
# when "0000001010" => data <= "101111101";
# when "0000001011" => data <= "100000000";
# when "0000001100" => data <= "100001100";
# when "0000001101" => data <= "100100011";
# when "0000001110" => data <= "100000001";
# when "0000001111" => data <= "011111111";
# when "0000010000" => data <= "011101111";
# when "0000010001" => data <= "101110110";
# when "0000010010" => data <= "101000000";
# when "0000010011" => data <= "100000000";
# when "0000010100" => data <= "100001111";
# when "0000010101" => data <= "011111111";
# ...
